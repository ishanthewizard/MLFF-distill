# %%
from ase.io import iread

# Load all frames from the specified XYZ file
xyz_path = "/global/homes/y/yuejian/project/MLFF-distill/m5024/distillation_project/data/lmdb_for_distillation/all_salt_first_250ps/train/combined_train_frames.xyz"
traj_iter = iread(xyz_path)

# To know the length of trajectory (number of frames):
traj_list = list(traj_iter)
traj_length = len(traj_list)

print(f"Number of frames in trajectory: {traj_length}")

# Optional: print info for the first frame
first_atoms = traj_list[0]
print(first_atoms)
print(first_atoms.positions)
print(first_atoms.get_chemical_symbols())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 8
#       5 traj_iter = iread(xyz_path)
#       7 # To know the length of trajectory (number of frames):
# ----> 8 traj_list = list(traj_iter)
#       9 traj_length = len(traj_list)
#      11 print(f"Number of frames in trajectory: {traj_length}")
#
# File /pscratch/sd/y/yuejian/envs/fairchemV2/lib/python3.10/site-packages/ase/io/formats.py:828, in iread(filename, index, format, parallel, do_not_split_by_at_sign, **kwargs)
#     825 format = format or filetype(filename, read=isinstance(filename, str))
#     826 io = get_ioformat(format)
# --> 828 yield from _iread(filename, index, format, io, parallel=parallel,
#     829                   **kwargs)
#
# File /pscratch/sd/y/yuejian/envs/fairchemV2/lib/python3.10/site-packages/ase/parallel.py:292, in parallel_generator.<locals>.new_generator(*args, **kwargs)
# ...
